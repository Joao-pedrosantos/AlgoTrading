# %% [markdown]
# # Algotrading - Aula 2 - Data
#
# Analisando Market Data em diferentes níveis
# ___
#
# Vamos começar importando algumas bibliotecas úteis

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
#from scipy import stats

from IPython import display

# %% [markdown]
# Instalar também uma biblioteca também útil para pegar dados de fechamento direito do yahoo finance:

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (0.2.65)
# Requirement already satisfied: pandas>=1.3.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (6.32.0)
# Requirement already satisfied: websockets>=13.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.1)
# Requirement already satisfied: cffi>=1.12.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: pycparser in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.5.0)

# %% [markdown]
# Agora vamos baixar dados de fechamento (**Historical Data**) de 6 meses diretamente do site

# %%
import yfinance as yf
ticker = '^BVSP'  # Bovespa Index

start_date = '2024-07-31'
end_date =  '2025-07-31'

ibov = yf.download(ticker, start=start_date, end=end_date, interval='1d', auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Vamos dar uma olhadinha nos dados

# %%
print(ibov)
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP     ^BVSP
# Date
# 2024-07-31  127652.0  127853.0  126139.0  126139.0   9471900
# 2024-08-01  127395.0  128762.0  127150.0  127652.0   9814200
# 2024-08-02  125854.0  128104.0  125731.0  127395.0   9950900
# 2024-08-05  125270.0  125851.0  123073.0  125851.0  10886100
# 2024-08-06  126267.0  126966.0  125261.0  125270.0  10052600
# ...              ...       ...       ...       ...       ...
# 2025-07-24  133808.0  135363.0  133648.0  135357.0   5976800
# 2025-07-25  133524.0  134204.0  133285.0  133820.0   5560900
# 2025-07-28  132129.0  133902.0  131550.0  133538.0   6625600
# 2025-07-29  132726.0  133346.0  132130.0  132130.0   6324800
# 2025-07-30  133990.0  134368.0  131883.0  132702.0   8655300
#
# [249 rows x 5 columns]

# %% [markdown]
# Primeiro vamos remover a estrutura multiindex (nome do instrumento)

# %%
ibov.columns = ibov.columns.get_level_values(0)
print(ibov)
# Out:
# Price          Close      High       Low      Open    Volume
# Date
# 2024-07-31  127652.0  127853.0  126139.0  126139.0   9471900
# 2024-08-01  127395.0  128762.0  127150.0  127652.0   9814200
# 2024-08-02  125854.0  128104.0  125731.0  127395.0   9950900
# 2024-08-05  125270.0  125851.0  123073.0  125851.0  10886100
# 2024-08-06  126267.0  126966.0  125261.0  125270.0  10052600
# ...              ...       ...       ...       ...       ...
# 2025-07-24  133808.0  135363.0  133648.0  135357.0   5976800
# 2025-07-25  133524.0  134204.0  133285.0  133820.0   5560900
# 2025-07-28  132129.0  133902.0  131550.0  133538.0   6625600
# 2025-07-29  132726.0  133346.0  132130.0  132130.0   6324800
# 2025-07-30  133990.0  134368.0  131883.0  132702.0   8655300
#
# [249 rows x 5 columns]

# %% [markdown]
# Começando a explorar os dados

# %%
# Medidas Resumo
ibov.Close.describe()
# Out:
# count       249.000000
# mean     130703.550201
# std        5456.770609
# min      118533.000000
# 25%      126267.000000
# 50%      131043.000000
# 75%      135173.000000
# max      141478.000000
# Name: Close, dtype: float64

# %%
# Histograma (de preços)
ibov.Close.plot.hist(density=True);

# %% [markdown]
# Pergunta: Isso faz sentido?
# ___
# Para montar o gráfico de candlestick, vamos instalar mais uma biblioteca:

# %%
# !pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from mplfinance) (3.10.5)
# Requirement already satisfied: pandas in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from mplfinance) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (25.0)
# Requirement already satisfied: pillow>=8 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/joao/Documents/AlgoTrading/.venv/lib/python3.12/site-packages (from pandas->mplfinance) (2025.2)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import mplfinance as mpf
mpf.plot(ibov, type="candle", volume=True, style="yahoo", title="^BVSP Candlestick Chart", figsize=(25,16))

# %% [markdown]
# ___
# Conforme comentado na aula passa, de onde vem esses preços?
# Toda história de um dia pode ser contada em 4 pontos (OHLC)?
#
# Vamos analisar o **RAW DATA** do arquivo de negociações (trades)

# %%
brkm5 = pd.read_csv('NEG_BRKM5.csv')
brkm5.head(25)
# Out:
#    Data Sessao  Ativo  Nr.Negocio  Preco  Quantidade          Hora  Anulacao  \
# 0   2019-09-13  BRKM5          10  30.09         100  10:05:00.000         1
# 1   2019-09-13  BRKM5          20  30.09         100  10:05:00.000         1
# 2   2019-09-13  BRKM5         100  30.09         100  10:05:00.000         1
# 3   2019-09-13  BRKM5          90  30.09         100  10:05:00.000         1
# 4   2019-09-13  BRKM5          80  30.09         100  10:05:00.000         1
# 5   2019-09-13  BRKM5          70  30.09         500  10:05:00.000         1
# 6   2019-09-13  BRKM5          30  30.09         200  10:05:00.000         1
# 7   2019-09-13  BRKM5          40  30.09         100  10:05:00.000         1
# 8   2019-09-13  BRKM5          50  30.09         200  10:05:00.000         1
# 9   2019-09-13  BRKM5          60  30.09         100  10:05:00.000         1
# 10  2019-09-13  BRKM5         110  30.10         100  10:05:00.047         1
# 11  2019-09-13  BRKM5         120  30.17         100  10:05:24.191         1
# 12  2019-09-13  BRKM5         140  30.12         100  10:05:29.573         1
# 13  2019-09-13  BRKM5         130  30.12         200  10:05:29.573         1
# 14  2019-09-13  BRKM5         150  30.12         100  10:05:29.573         1
# 15  2019-09-13  BRKM5         160  30.12         100  10:05:29.574         1
# 16  2019-09-13  BRKM5         170  30.16         100  10:05:45.110         1
# 17  2019-09-13  BRKM5         180  30.14         200  10:05:47.115         1
# 18  2019-09-13  BRKM5         190  30.14         100  10:05:59.795         1
# 19  2019-09-13  BRKM5         200  30.14         100  10:06:12.945         1
# 20  2019-09-13  BRKM5         210  30.14         100  10:07:07.726         1
# 21  2019-09-13  BRKM5         220  30.14         100  10:07:26.455         1
# 22  2019-09-13  BRKM5         230  30.14         200  10:07:26.455         1
# 23  2019-09-13  BRKM5         240  30.16         400  10:07:28.805         1
# 24  2019-09-13  BRKM5         250  30.17         100  10:07:28.824         1
#
#       Data CPA      Num CPA     Data VDA      Num VDA  Comprador  Vendedor
# 0   2019-09-13  84793902007  84793916889  84793916889         45       147
# 1   2019-09-13  84793918583  84793917059  84793917059        308       147
# 2   2019-09-13  84793903323  84793895663  84793895663        308         3
# 3   2019-09-13  84793902822  84793908650  84793908650        308       308
# 4   2019-09-13  84793895660  84793908650  84793908650          3       308
# 5   2019-09-13  84793921104  84793908650  84793908650          3       308
# 6   2019-09-13  84793917259  84793919867  84793919867          3        85
# 7   2019-09-13  84793917259  84793923595  84793923595          3       147
# 8   2019-09-13  84793917259  84793908650  84793908650          3       308
# 9   2019-09-13  84793903252  84793908650  84793908650         40       308
# 10  2019-09-13  84793925187  84793925273  84793925273       1618       147
# 11  2019-09-13  84793927005  84793926613  84793926613       1618        40
# 12  2019-09-13  84793925183  84793927247  84793927247        120       147
# 13  2019-09-13  84793927006  84793927247  84793927247       1618       147
# 14  2019-09-13  84793927127  84793927247  84793927247         85       147
# 15  2019-09-13  84793927251  84793927247  84793927247          8       147
# 16  2019-09-13  84793928369  84793927823  84793927823          3       147
# 17  2019-09-13  84793927970  84793928449  84793928449       1618         3
# 18  2019-09-13  84793928451  84793929360  84793929360       1618        85
# 19  2019-09-13  84793928451  84793931211  84793931211       1618        77
# 20  2019-09-13  84793931224  84793934405  84793934405       1618       147
# 21  2019-09-13  84793931224  84793936856  84793936856       1618       147
# 22  2019-09-13  84793932202  84793936856  84793936856         90       147
# 23  2019-09-13  84793936990  84793927823  84793927823         40       147
# 24  2019-09-13  84793937078  84793926613  84793926613         40        40

# %% [markdown]
# Legenda das colunas:
#
# ```
# Data Sessão      Data de sessão
# Ativo            Símbolo do Instrumento
# Nr.Negócio       Número do negócio
# Preco            Preço do negócio
# Quantidade       Quantidade negociada
# Hora             Horário da negociação (formato HH:MM:SS.NNN)
# Anulacao         Indicador de Anulação: "1" - ativo / "2" - cancelado
# Data CPA         Data da oferta de compra
# Num CPA          Número sequencial da oferta de compra
# Data VDA         Data da oferta de venda
# Num VDA          Número sequencial da oferta de venda
# Comprador        Código de identificação da corretora de compra
# Vendedor         Código de identificação da corretora de venda
# ```
#
# Ou seja, cada linha do DataFrame representa uma operação que ocorreu em um determinado dia.
#
# Como é montado o candle desse dia?

# %%
print('Open: {}'.format(brkm5.iloc[0,:]['Preco'])) # Primeiro
print('High: {}'.format(max(brkm5['Preco']))) # Máximo
print('Low: {}'.format(min(brkm5['Preco']))) # Mínimo
print('Close: {}'.format(brkm5.iloc[-1,:]['Preco'])) # Último
# Out:
# Open: 30.09
# High: 30.28
# Low: 29.52
# Close: 29.76

# %% [markdown]
# Quantas operações aconteceram nesse dia?

# %%
len(brkm5)
# Out:
# 7296

# %% [markdown]
# Vamos dar uma olhadinha no gráfico de preços

# %%
brkm5['Preco'].plot();

# %% [markdown]
# Faz sentido esse gráfico? O que representa o eixo x?
# ___
#
# Vamos dar uma olhada em algumas informações que não tínhamos nos dados do yahoo finance:

# %%
# Número de negócios por hora do dia:

brkm5['Hora'].str[:3].value_counts().sort_index().plot(kind='bar');

# %%
# Número de negócios minuto a minuto

minutes = brkm5['Hora'].str[:5].value_counts().sort_index()
minutes.plot(kind='bar', figsize=(20,3), xticks=range(0, len(minutes),10));

# %%
# Quantos negócios no primeiro minuto do dia?

min1 = brkm5[brkm5['Hora'].str.contains('10:05:')]
len(min1)
# Out:
# 19

# %%
# Candle do primeiro minuto do dia

print('Open: {}'.format(min1.iloc[0,:]['Preco']))
print('High: {}'.format(max(min1['Preco'])))
print('Low: {}'.format(min(min1['Preco'])))
print('Close: {}'.format(min1.iloc[-1,:]['Preco']))
# Out:
# Open: 30.09
# High: 30.17
# Low: 30.09
# Close: 30.14

# %% [markdown]
# Lembrando que o candle não dá noção de ordem dos acontecimentos, vendo ponto a ponto:

# %%
min1['Preco'].plot();

# %% [markdown]
# Vamos separar apenas os últimos trades de cada minuto

# %%
brkm5['Minuto'] = brkm5['Hora'].str[:5]
brkm5.groupby(by='Minuto').last()['Preco'].plot();

# %% [markdown]
# Agora uma comparação do gráfico tick-by-tick com o close de cada minuto

# %%
len(brkm5.groupby(by='Minuto').last()['Preco'])
# Out:
# 412

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
brkm5.groupby(by='Minuto').last()['Preco'].plot();
plt.subplot(1,2,2)
brkm5['Preco'].plot();

# %% [markdown]
# Você consegue notar alguma diferença?

# %%
print(len(brkm5.groupby(by='Minuto').last()['Preco']))
print(len(brkm5['Preco']))
# Out:
# 412
# 7296

# %% [markdown]
# Selecionando apenas os primeiros 50 pontos

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
brkm5.groupby(by='Minuto').last().iloc[:50,:]['Preco'].plot();
plt.subplot(1,2,2)
brkm5.iloc[:50,:]['Preco'].plot();

# %% [markdown]
# Conclusão: apesar de parecidos, os gráficos não são comparáveis, pois os eixos significam unidades distintas e o tick-by-tick possuim muito mais pontos.
# ___
#
# E o **Intraday Data**? Basta escolher uma discretização (normalmente em minutos) e agrupar os preços

# %%
# Montando o candle
minuto = brkm5.groupby(by='Minuto')

#intra.index = pd.to_datetime(intra.index)

intra = pd.DataFrame({'date': pd.to_datetime(minuto.first().index), 
                      'open': minuto.first()['Preco'], 
                      'high': minuto.max()['Preco'],
                      'low': minuto.min()['Preco'], 
                      'close': minuto.last()['Preco'] })

intra = intra.set_index('date')

intra.head()
# Out:
# /tmp/ipykernel_16616/3170076257.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   intra = pd.DataFrame({'date': pd.to_datetime(minuto.first().index),
#                       open   high    low  close
# date
# 2025-08-19 10:05:00  30.09  30.17  30.09  30.14
# 2025-08-19 10:06:00  30.14  30.14  30.14  30.14
# 2025-08-19 10:07:00  30.14  30.28  30.14  30.19
# 2025-08-19 10:08:00  30.15  30.15  30.15  30.15
# 2025-08-19 10:10:00  30.16  30.19  30.16  30.19

# %%
mpf.plot(intra.iloc[-100:],type='candle', figsize=(20,5))

# %% [markdown]
# E os dados de BID/ASK?
#
# Estão em outros arquivos:

# %%
brkm5_cpa = pd.read_csv('OFER_CPA_BRKM5.csv')
brkm5_cpa.head(25)
# Out:
#    Data Sessao  Ativo  Sentido      Num CPA  GenerationID CPA  Evento  \
# 0   2019-09-13  BRKM5        1  84534855732          14764482       1
# 1   2019-09-13  BRKM5        1  84534855733          14764483       1
# 2   2019-09-13  BRKM5        1  84534960446          15073161       1
# 3   2019-09-13  BRKM5        1  84535773323          18030371       1
# 4   2019-09-13  BRKM5        1  84544071552           9479628       1
# 5   2019-09-13  BRKM5        1  84583291318           3515804       2
# 6   2019-09-13  BRKM5        1  84583291318           3543967       2
# 7   2019-09-13  BRKM5        1  84583291318           4864129       2
# 8   2019-09-13  BRKM5        1  84583291318          10200859       2
# 9   2019-09-13  BRKM5        1  84583291318          10215914       2
# 10  2019-09-13  BRKM5        1  84583291318          10258841       2
# 11  2019-09-13  BRKM5        1  84583291318          11664530       1
# 12  2019-09-13  BRKM5        1  84583291318          22190807       2
# 13  2019-09-13  BRKM5        1  84583291318          23716676       2
# 14  2019-09-13  BRKM5        1  84583291318          26407159       2
# 15  2019-09-13  BRKM5        1  84583291318          27155625       2
# 16  2019-09-13  BRKM5        1  84583291318          31656985       2
# 17  2019-09-13  BRKM5        1  84618263194           9875085       1
# 18  2019-09-13  BRKM5        1  84618263194           9875315       2
# 19  2019-09-13  BRKM5        1  84618263369           9875439       1
# 20  2019-09-13  BRKM5        1  84618636893          11079975       1
# 21  2019-09-13  BRKM5        1  84618636893          13308232       2
# 22  2019-09-13  BRKM5        1  84618636893          38479473       2
# 23  2019-09-13  BRKM5        1  84619036974           3197144       2
# 24  2019-09-13  BRKM5        1  84619036974           3230113       2
#
#     Hora Prioridade  Ind de Prioridade  Preco  Qtd.Total  Qtd.Negociada  \
# 0   09:45:17.012000         2147483647  45.90        100              0
# 1   09:45:17.023000         2147483647  46.77        100              0
# 2   10:26:20.679000         2147483647  46.05        100              0
# 3   12:40:20.181000         2147483647  47.50        200              0
# 4   11:10:15.483000         2147483647  46.95        100              0
# 5   11:54:31.586000         2147483647  23.75        100              0
# 6   11:55:37.864000         2147483647  23.23        100              0
# 7   13:11:29.119000         2147483647  23.75        100              0
# 8   10:23:38.115000         2147483647  28.89        100              0
# 9   10:24:20.036000         2147483647  28.88        100              0
# 10  10:26:18.542000         2147483647  23.45        100              0
# 11  12:33:18.873000         2147483647  28.89        100              0
# 12  11:12:53.197000         2147483647  23.75        100              0
# 13  10:08:25.157000         2147483647  25.25        100              0
# 14  11:42:34.900000         2147483647  23.75        100              0
# 15  16:51:15.003000         2147483647  24.68        100              0
# 16  15:08:46.719000         2147483647  28.89        100              0
# 17  09:57:30.573000         2147483647  25.52      20000              0
# 18  09:57:59.063000         2147483647  25.26      20000              0
# 19  09:58:08.757000         2147483647  25.12      20000              0
# 20  10:53:57.649000         2147483647  27.77       1000              0
# 21  12:23:55.581000         2147483647  17.77       1000              0
# 22  16:10:01.030000         2147483647  12.77       1000              0
# 23  12:59:24.315000         2147483647  24.20        100              0
# 24  13:00:31.607000         2147483647  23.84        100              0
#
#    Data Oferta      Data de Entrada  Estado  Condicao  Corretora
# 0   2019-04-10  2019-04-10 09:45:17       0         0          3
# 1   2019-04-10  2019-04-10 09:45:17       0         0          3
# 2   2019-04-10  2019-04-10 10:26:20       0         0        114
# 3   2019-04-10  2019-04-10 12:40:20       0         0         72
# 4   2019-04-16  2019-04-16 11:10:15       0         0          3
# 5   2019-08-26  2019-08-26 11:54:31       5         0         27
# 6   2019-08-26  2019-08-26 11:55:37       5         0         27
# 7   2019-08-12  2019-08-12 13:11:29       5         0         27
# 8   2019-06-04  2019-06-04 10:23:38       5         0         27
# 9   2019-06-04  2019-06-04 10:24:20       5         0         27
# 10  2019-06-04  2019-06-04 10:26:18       5         0         27
# 11  2019-05-14  2019-05-14 12:33:18       0         0         27
# 12  2019-08-07  2019-08-07 11:12:53       5         0         27
# 13  2019-07-18  2019-07-18 10:08:25       5         0         27
# 14  2019-08-01  2019-08-01 11:42:34       5         0         27
# 15  2019-06-27  2019-06-27 16:51:15       5         0         27
# 16  2019-05-16  2019-05-16 15:08:46       5         0         27
# 17  2019-06-04  2019-06-04 09:57:30       0         0         93
# 18  2019-06-04  2019-06-04 09:57:59       5         0         93
# 19  2019-06-04  2019-06-04 09:58:08       0         0         93
# 20  2019-06-04  2019-06-04 10:53:57       0         0          3
# 21  2019-06-04  2019-06-04 12:23:55       5         0          3
# 22  2019-08-15  2019-08-15 16:10:01       5         0          3
# 23  2019-06-17  2019-06-17 12:59:24       5         0         27
# 24  2019-06-17  2019-06-17 13:00:31       5         0         27

# %%
brkm5_vda = pd.read_csv('OFER_VDA_BRKM5.csv')
brkm5_vda.head()
# Out:
#   Data Sessao  Ativo  Sentido      Num VDA  GenerationID VDA  Evento  \
# 0  2019-09-13  BRKM5        2  84496155021           9361896       2
# 1  2019-09-13  BRKM5        2  84496155021          12026287       2
# 2  2019-09-13  BRKM5        2  84496155021          19591674       2
# 3  2019-09-13  BRKM5        2  84499567268          31398288       2
# 4  2019-09-13  BRKM5        2  84528551583           9235057       2
#
#    Hora Prioridade  Ind de Prioridade  Preco  Qtd.Total  Qtd.Negociada  \
# 0  10:49:53.488000         2147483647   40.0       3000              0
# 1  15:14:56.133000         2147483647   45.0       3000              0
# 2  17:30:01.496000         2147483647   34.0       1000              0
# 3  09:45:25.486000         2147483647   48.0        400              0
# 4  17:36:48.708000         2147483647   49.5        200              0
#
#   Data Oferta      Data de Entrada  Estado  Condicao  Corretora
# 0  2019-07-16  2019-07-16 10:49:53       5         0          3
# 1  2019-06-25  2019-06-25 15:14:56       5         0          3
# 2  2019-08-06  2019-08-06 17:30:01       5         0          3
# 3  2019-08-22  2019-08-22 09:45:25       5         0          3
# 4  2019-08-12  2019-08-12 17:36:48       5         0          3

# %%
print(len(brkm5_cpa))
print(len(brkm5_vda))
# Out:
# 36406
# 39875

# %% [markdown]
# E tem muita coisa para explorar nesses dados como por exemplo:
#
# 1. Proporção de ordens que foram executadas?
# 2. Qual é a ordem de compra mais longe (baixa) do preço?
# 3. Qual é o formato da fila ao longo do dia?
# 4. Em qual lado teve mais agressões na fila?
# 5. Existiu alguma ordem de tamanho desproporcional?
# 6. O que são *Heikin Ashi Chart* e *Renko Chart*?
#
# Notem que é possível contar a história do dia todo com os 3 arquivos (NEG, CPA e VDA)
#
# Ainda, a quantidade de dados gerados diariamente é enorme. Nesse exemplo pegamos uma ação não muito negociada e os dados de apenas 1 dia.
